# %%
import pybullet_envs
# Don't forget to install PyBullet!
from gym import make
import numpy as np
import torch
from torch import nn
from torch.distributions import MultivariateNormal
from torch.nn import functional as F
from torch.optim import Adam
import random

ENV_NAME = "Walker2DBulletEnv-v0"

LAMBDA = 0.95
GAMMA = 0.99

ACTOR_LR = 2e-4
CRITIC_LR = 1e-4

CLIP = 0.2
ENTROPY_COEF = 1e-2
BATCHES_PER_UPDATE = 64
BATCH_SIZE = 64

MIN_TRANSITIONS_PER_UPDATE = 2048
MIN_EPISODES_PER_UPDATE = 4

ITERATIONS = 1000

# %%
import io
import base64
from IPython.display import HTML

video = io.open('./gym-results/openaigym.video.%s.video000000.mp4' % env.file_infix, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''
    <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''
     .format(encoded.decode('ascii')))
# Out:
#     <video width="360" height="auto" alt="test" controls><source src="..." type="video/mp4" /></video>

# %%
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('Walker2d-v2')
env.reset()
plt.figure(figsize=(9,9))
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(100):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ad62777dfa15> in <module>
#      11 for _ in range(100):
#      12     img.set_data(env.render(mode='rgb_array')) # just update the data
# ---> 13     display.display(plt.gcf())
#      14     display.clear_output(wait=True)
#      15     action = env.action_space.sample()
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2052                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2277                 # need this conditional....
#    2278                 try:
# -> 2279                     bbox = ax.get_tightbbox(renderer,
#    2280                             bbox_extra_artists=bbox_extra_artists)
#    2281                 except TypeError:
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4385             bb.append(self._right_title.get_window_extent(renderer))
#    4386
# -> 4387         bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4388         if bb_yaxis:
#    4389             bb.append(bb_yaxis)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
# -> 1142         self._update_label_position(renderer)
#    1143
#    1144         # go back to just this axis's tick labels
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2305         # get bounding boxes for this axis and any siblings
#    2306         # that have been set by `fig.align_ylabels()`
# -> 2307         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2308
#    2309         x, y = self.label.get_position()
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2289         # if we want to align labels from other axes:
#    2290         for axx in grp.get_siblings(self.axes):
# -> 2291             ticks_to_draw = axx.yaxis._update_ticks(renderer)
#    2292             tlb, tlb2 = axx.yaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2293             bboxes.extend(tlb)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/ticker.py in __call__(self)
#    1983     def __call__(self):
#    1984         vmin, vmax = self.axis.get_view_interval()
# -> 1985         return self.tick_values(vmin, vmax)
#    1986
#    1987     def tick_values(self, vmin, vmax):
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1991         vmin, vmax = mtransforms.nonsingular(
#    1992             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1993         locs = self._raw_ticks(vmin, vmax)
#    1994
#    1995         prune = self._prune
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1930         if self._nbins == 'auto':
#    1931             if self.axis is not None:
# -> 1932                 nbins = np.clip(self.axis.get_tick_space(),
#    1933                                 max(1, self._min_n_ticks - 1), 9)
#    1934             else:
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2537         ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2538         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# -> 2539         tick = self._get_tick(True)
#    2540         # Having a spacing of at least 2 just looks good.
#    2541         size = tick.label1.get_size() * 2.0
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2192         else:
#    2193             tick_kw = self._minor_tick_kw
# -> 2194         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2195
#    2196     def _get_label(self):
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172         self.apply_tickdir(tickdir)
#     173
# --> 174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     587         # x in axes coords, y in data coords
#     588
# --> 589         l = mlines.Line2D((0,), (0,),
#     590                           color=self._color,
#     591                           marker=self._tickmarkers[0],
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     384         self._color = None
#     385         self.set_color(color)
# --> 386         self._marker = MarkerStyle(marker, fillstyle)
#     387
#     388         self._markevery = None
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     243         self._marker_function = None
#     244         self.set_fillstyle(fillstyle)
# --> 245         self.set_marker(marker)
#     246
#     247     def _recache(self):
#
# ~/.pyenv/versions/3.8.7/lib/python3.8/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     292         return self._marker
#     293
# --> 294     def set_marker(self, marker):
#     295         if (isinstance(marker, np.ndarray) and marker.ndim == 2 and
#     296                 marker.shape[1] == 2):
#
# KeyboardInterrupt:
